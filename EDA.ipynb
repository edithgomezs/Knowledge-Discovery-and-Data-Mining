# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('full_data_clean_n10000.csv')
df.head()
# Out:
#    ELEVATION_dest  TEMP_dest  DEWP_dest  STP_dest  VISIB_dest  WDSP_dest  \
# 0             3.4       75.5       64.3      23.2         9.8        5.7
# 1           421.2       88.6       65.8     964.7        20.8        7.7
# 2           243.2       55.0       43.0     989.0         8.2        7.7
# 3            13.4       86.3       74.3      11.2         9.9        3.2
# 4             8.2       60.7       41.5     999.9        10.0       11.3
#
#    MXSPD_dest  MAX_dest  MIN_dest  PRCP_dest  ...  WheelsOff  WheelsOn  \
# 0        12.0      82.0      70.0       0.00  ...        522       606
# 1        21.0     104.0      78.8       0.00  ...        551       804
# 2        14.0      64.0      48.0       0.07  ...       1757      2210
# 3         8.9      95.0      78.1       0.00  ...       1302      1649
# 4        16.9      69.8      50.0       0.00  ...       1226      1326
#
#    TaxiIn  CRSArrTime  ArrDelay  Diverted  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
df.columns
# Out:
# Index(['ELEVATION_dest', 'TEMP_dest', 'DEWP_dest', 'STP_dest', 'VISIB_dest',
#        'WDSP_dest', 'MXSPD_dest', 'MAX_dest', 'MIN_dest', 'PRCP_dest',
#        'SNDP_dest', 'LATITUDE_dest', 'LONGITUDE_dest', 'Clear_dest',
#        'Fog_dest', 'Rain_dest', 'Snow_dest', 'Hail_dest', 'Thunder_dest',
#        'Tornada_dest', 'ELEVATION_origin', 'TEMP_origin', 'DEWP_origin',
#        'STP_origin', 'VISIB_origin', 'WDSP_origin', 'MXSPD_origin',
#        'MAX_origin', 'MIN_origin', 'PRCP_origin', 'SNDP_origin',
#        'LATITUDE_origin', 'LONGITUDE_origin', 'Clear_origin', 'Fog_origin',
#        'Rain_origin', 'Snow_origin', 'Hail_origin', 'Thunder_origin',
#        'Tornada_origin', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'Date',
#        'Flight_Number_Reporting_Airline', 'OriginCityName', 'OriginState',
#        'DestCityName', 'DestState', 'CRSDepTime', 'DepDelay', 'TaxiOut',
#        'WheelsOff', 'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrDelay', 'Diverted',
# ...

# %%
df['dep_delay_class'] = np.where(df['DepDelay']>=15.0, '1', '0')

df['dep_delay_class'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: dep_delay_class, dtype: object

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='dep_delay_class', data=df).set(title="DepDelay Class Count")
plt.show()

# %%
df['arr_delay_class'] = np.where(df['ArrDelay']>=15.0, '1', '0')

df['arr_delay_class'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: arr_delay_class, dtype: object

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='arr_delay_class', data=df).set(title="ArrDelay Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.boxplot(x=df['DepDelay']).set(title="Boxplot for DepDelay")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.boxplot(x=df['ArrDelay']).set(title="Boxplot for ArrDelay")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.scatterplot(x=df['ArrDelay'], y=df['TEMP_dest']).set(title="ArrDelay v. TEMP_dest")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.scatterplot(x=df['DepDelay'], y=df['TEMP_origin']).set(title="DepDelay v. TEMP_origin")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.scatterplot(x=df['DepDelay'], y=df['VISIB_origin']).set(title="DepDelay v. VISIB_origin")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.scatterplot(x=df['DepDelay'], y=df['DEWP_origin']).set(title="DepDelay v. DEWP_origin")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.scatterplot(x=df['DepDelay'], y=df['STP_origin']).set(title="DepDelay v. STP_origin")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.scatterplot(x=df['DepDelay'], y=df['WDSP_origin']).set(title="DepDelay v. WDSP_origin")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='Clear_origin', data=df).set(title="Clear_origin Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='Fog_origin', data=df).set(title="Fog_origin Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='Rain_origin', data=df).set(title="Rain_origin Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='Snow_origin', data=df).set(title="Snow_origin Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='Hail_origin', data=df).set(title="Hail_origin Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='Thunder_origin', data=df).set(title="Thunder_origin Class Count")
plt.show()

# %%
plt.subplots(figsize=(10,6))
sns.histplot(data=df, x='Year')
plt.show()

# %%
df1 = df[['ELEVATION_origin', 'TEMP_origin', 'DEWP_origin',
          'STP_origin', 'VISIB_origin', 'WDSP_origin', 'MXSPD_origin',
          'MAX_origin', 'MIN_origin', 'PRCP_origin', 'SNDP_origin',
          'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'Date',
          'Flight_Number_Reporting_Airline', 'OriginCityName', 'OriginState',
          'DestCityName', 'DestState', 'CRSDepTime', 'DepDelay', 'TaxiOut',
          'WheelsOff', 'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrDelay', 'Diverted',
          'CRSElapsedTime', 'ActualElapsedTime', 'AirTime', 'Distance']]

corr = df1.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.subplots(figsize=(10, 10))

sns.heatmap(corr, mask=mask, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
